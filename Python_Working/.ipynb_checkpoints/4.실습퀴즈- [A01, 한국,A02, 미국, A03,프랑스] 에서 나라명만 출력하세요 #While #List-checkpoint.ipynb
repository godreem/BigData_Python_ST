# %% [markdown]
# ## ["A01", "한국", "A02", "미국", "A03","프랑스"] 에서 나라명만 출력하세요

# %%
nations = ["A01", "한국", "A02", "미국", "A03","프랑스"]

# %%
len(nations)
# Out:
# 6

# %%
i=0
while i < len(nations):
    if i%2 == 1:
        print(nations[i])
    i=i+1
# Out:
# 한국
# 미국
# 프랑스

# %%
i=1
if i%2 == 1:
    print(nations[i])
# Out:
# 한국
